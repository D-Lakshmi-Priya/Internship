# %% [markdown]
# <a href="https://colab.research.google.com/github/D-Lakshmi-Priya/pandas/blob/main/pyplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install matplotlib

# %%
import random
import random
X = []
Y = []
[X.append(random.randint(0,50)) for _ in range(35)]
[Y.append(random.randint(0,50)) for _ in range(35)]
print(X)
print(Y)
# Out:
# [2, 47, 20, 17, 50, 20, 21, 27, 10, 2, 33, 6, 22, 49, 34, 19, 32, 24, 2, 2, 10, 42, 12, 50, 11, 48, 22, 3, 18, 31, 16, 34, 13, 6, 20]
# [32, 34, 14, 0, 40, 21, 41, 2, 44, 42, 38, 45, 5, 8, 11, 38, 47, 22, 4, 34, 40, 16, 24, 7, 50, 1, 21, 2, 15, 44, 33, 23, 38, 42, 23]

# %%
from matplotlib import pyplot as plt

# %%
plt.scatter(X,Y)

# %%
plt.plot(X,Y)
