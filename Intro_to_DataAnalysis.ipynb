# %% [markdown]
# <a href="https://colab.research.google.com/github/D-Lakshmi-Priya/Internship/blob/main/Introd_to_DataAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# %%
a1=[]
a2=[]
a3=[]
a4=[]
a5=[]

# %%
for _ in range(1000):
    a1.append(random.randint(0,100))
    a2.append(random.randint(50,70))
    a3.append(random.randint(10,20))
    a4.append(random.randint(5,10))
    a5.append(random.randint(20,100))

# %%
df = {
     'grade':a1,
     'weight':a2,
     'friends':a3,
     'cousins':a4,
     'projects':a5
}

# %%
import pandas as pd

# %%
df1 = pd.DataFrame(df)
df1
# Out:
#      grade  weight  friends  cousins  projects
# 0       18      65       15        7        71
# 1       64      61       11        7        36
# 2       40      65       10       10        41
# 3       40      69       18        9        57
# 4        2      59       15        8        34
# ..     ...     ...      ...      ...       ...
# 995     69      59       13        5        38
# 996     64      52       15        8        86
# 997     59      61       19        5        80
# 998     39      53       19       10        86
# 999     43      56       15        8        61
#
# [1000 rows x 5 columns]

# %%
df1.describe()
# Out:
#              grade       weight     friends      cousins     projects
# count  1000.000000  1000.000000  1000.00000  1000.000000  1000.000000
# mean     49.333000    59.990000    15.02800     7.508000    60.833000
# std      28.993184     6.100747     3.10594     1.710222    23.512208
# min       0.000000    50.000000    10.00000     5.000000    20.000000
# 25%      24.000000    55.000000    12.00000     6.000000    41.000000
# 50%      47.000000    60.000000    15.00000     7.000000    62.000000
# 75%      75.000000    66.000000    18.00000     9.000000    81.000000
# max     100.000000    70.000000    20.00000    10.000000   100.000000

# %%
df1['grade'].count()
# Out:
# 1000

# %%
freind15 = df1['friends']>15
df1[freind15]
# Out:
#      grade  weight  friends  cousins  projects
# 3       40      69       18        9        57
# 13      73      67       18       10        64
# 15      96      63       17        5        20
# 19      63      58       20        9        63
# 20      71      69       20        9        68
# ..     ...     ...      ...      ...       ...
# 990     99      67       16        5        80
# 991     99      64       19        9        49
# 993     53      68       17       10        66
# 997     59      61       19        5        80
# 998     39      53       19       10        86
#
# [440 rows x 5 columns]

# %%
grade75 = df1['grade']>75
df1[grade75]
# Out:
#      grade  weight  friends  cousins  projects
# 7       85      64       13        9        84
# 12      85      70       10        9        62
# 15      96      63       17        5        20
# 26      97      57       15       10        31
# 29      90      67       20        7        22
# ..     ...     ...      ...      ...       ...
# 984     89      67       18        8        31
# 985     91      57       19        8        98
# 987     99      70       10        8        62
# 990     99      67       16        5        80
# 991     99      64       19        9        49
#
# [241 rows x 5 columns]

# %%
df1[freind15 & grade75].value_counts()
# Out:
# grade  weight  friends  cousins  projects
# 76     56      16       8        78          1
# 92     50      20       5        35          1
# 94     60      19       10       48          1
#        56      16       10       100         1
#        55      19       7        87          1
#                                             ..
# 83     58      19       5        99          1
#        50      20       5        20          1
# 82     59      17       5        98          1
#        53      20       6        68          1
# 100    67      20       10       28          1
# Name: count, Length: 116, dtype: int64

# %%
df1[freind15 & grade75]['weight'].value_counts()
# Out:
# weight
# 67    16
# 57    10
# 68     7
# 50     7
# 61     6
# 55     6
# 52     6
# 58     6
# 59     5
# 54     5
# 63     5
# 70     5
# 53     5
# 66     5
# 60     4
# 62     4
# 64     4
# 69     3
# 56     3
# 65     2
# 51     2
# Name: count, dtype: int64

# %%
df1[freind15 & grade75]['friends']
# Out:
# 15     17
# 29     20
# 30     18
# 39     17
# 44     17
#        ..
# 972    17
# 984    18
# 985    19
# 990    16
# 991    19
# Name: friends, Length: 116, dtype: int64

# %%
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
df1[freind15 & grade75].plot()
# Out:
# <Axes: >

# %%
df1.plot()
# Out:
# <Axes: >

# %%
df1[freind15 & grade75].plot(kind='bar')
# Out:
# <Axes: >

# %%
df1[freind15 & grade75].plot(x='grade',y='projects')
# Out:
# <Axes: xlabel='grade'>

# %%
df1[freind15 & grade75].plot(x='cousins',y='friends',kind='pie')
# Out:
# <Axes: ylabel='friends'>

# %%
df1[freind15 & grade75].plot(x='grade',y='projects',kind='barh')
# Out:
# <Axes: ylabel='grade'>

# %%
df1[freind15 & grade75].plot(x='grade', y='projects',kind='bar')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.legend('Test Data')
plt.show()

# %%
fdf = df1[freind15 & grade75]
df1
# Out:
#      grade  weight  friends  cousins  projects
# 0       18      65       15        7        71
# 1       64      61       11        7        36
# 2       40      65       10       10        41
# 3       40      69       18        9        57
# 4        2      59       15        8        34
# ..     ...     ...      ...      ...       ...
# 995     69      59       13        5        38
# 996     64      52       15        8        86
# 997     59      61       19        5        80
# 998     39      53       19       10        86
# 999     43      56       15        8        61
#
# [1000 rows x 5 columns]

# %%
df1.to_csv(r'C:\Users\chinn.DARSINAM\OneDrive\Desktop\python.csv')
