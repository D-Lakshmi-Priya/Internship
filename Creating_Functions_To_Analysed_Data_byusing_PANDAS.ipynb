# %% [markdown]
# <a href="https://colab.research.google.com/github/D-Lakshmi-Priya/Internship/blob/main/Creating_Functions_To_Analysed_Data_byusing_PANDAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
datasetPath = '/content/drive/MyDrive/matches_1930_2022.csv'

# %%
df = pd.read_csv(datasetPath)

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
# ...

# %%
import random

# %%
age=[]
height=[]
weight=[]

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
# ...

# %%
df.shape
# Out:
# (964, 44)

# %%
# Loop comprehension
[age.append(random.randint(18,40)) for _ in range (964)]
print(f"Age is now having {len(age)}")
# Out:
# Age is now having 964

# %%
age
# Out:
# [34,
#  23,
#  37,
#  36,
#  34,
#  34,
#  38,
#  25,
#  40,
#  22,
#  22,
#  26,
#  23,
#  32,
#  40,
#  34,
#  21,
#  37,
#  22,
#  31,
#  38,
#  32,
#  25,
#  29,
#  34,
#  36,
#  33,
#  19,
#  39,
#  20,
#  40,
#  19,
#  37,
#  33,
#  33,
#  18,
#  27,
#  34,
#  32,
#  18,
#  30,
#  35,
#  28,
#  26,
#  39,
#  38,
#  24,
#  38,
#  26,
#  37,
#  30,
#  22,
#  33,
#  33,
#  21,
#  29,
#  38,
#  35,
#  31,
#  29,
#  35,
#  25,
#  35,
#  32,
#  35,
#  33,
#  37,
#  40,
#  29,
#  34,
#  37,
#  25,
#  28,
#  29,
#  27,
#  39,
#  32,
#  18,
#  35,
#  34,
#  18,
#  27,
#  29,
#  22,
#  19,
#  34,
#  20,
#  18,
#  34,
#  27,
#  22,
#  20,
#  36,
#  30,
#  26,
#  20,
#  24,
#  31,
#  21,
#  39,
#  28,
#  30,
#  19,
#  22,
#  40,
#  28,
#  26,
#  29,
#  18,
#  23,
#  22,
#  18,
#  26,
#  29,
#  24,
#  35,
#  27,
#  22,
#  34,
#  25,
#  28,
#  29,
#  34,
#  34,
#  40,
#  24,
#  25,
#  35,
#  32,
#  25,
#  39,
#  28,
#  27,
#  28,
#  23,
#  23,
#  30,
#  23,
#  32,
#  20,
#  27,
#  38,
# ...

# %%
# Adding a new column to the DFrame
# Syntax: df['NewColumnName'] = List/ Series of elements

# %%
df['YearsOfExperience'] = age

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
# ...

# %%
df['ASP']= df['YearsOfExperience'] - df['home_score']

# %%
df.shape
# Out:
# (964, 46)

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
# ...

# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt

# %%
df['ASP'].plot()
# Out:
# <Axes: >

# %%
df.plot(x='YearsOfExperience', y='ASP',kind='scatter',color='black')
# Out:
# <Axes: xlabel='YearsOfExperience', ylabel='ASP'>

# %%
df['ASP'].plot(kind='bar',color='pink')
# Out:
# <Axes: >

# %%
df.plot(x='YearsOfExperience', y=['ASP','home_score'],kind='bar',color=['orange','purple'])
# Out:
# <Axes: xlabel='YearsOfExperience'>

# %%
df.plot(x='ASP', y=['away_score','home_score'],kind='bar',color=['skyblue','purple'])
# Out:
# <Axes: xlabel='ASP'>

# %%
# Error:Same length -NaN - Not a Number - dtype - Numpy -0

# %%
# Function to get a graph
def getGraph(DataFrame,Column1,Column2):
   from matplotlib import pyplot as plt
   # Check the length of Column1 and Column2
   if len(DataFrame[Column1]) == len(DataFrame[Column2]):
     df.plot(x = Column1, y= Column2, kind='bar' , color=['Black','pink'])
     print('The graph/plot is successfully created ')
   else :
     print('please check the Column size once')

# %%
getGraph(df, 'home_score','away_score')
# Out:
# The graph/plot is successfully created
